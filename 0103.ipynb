# %%
#!/usr/bin/env python
# coding: utf-8

from sys import settrace

def tracer(frame, event, arg):
    func_name = frame.f_code.co_name
    line_no = frame.f_lineno
    f_locals = frame.f_locals
    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")
    return tracer

def foo(bar):
    buz = bar + 1
    bar *= buz
    if bar > buz:
        bar -= buz
    return bar + buz

old_tracer = settrace(tracer)
foo(10)
settrace(old_tracer)
# Out:
# event: call, function: __get__, lineno: 676, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: __get__, lineno: 684, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: __get__, lineno: 687, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: call, function: get, lineno: 629, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 630, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 631, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 632, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 666, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True}
# event: call, function: cast, lineno: 1737, locals: {'typ': ~G, 'val': True}
# event: line, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: get, lineno: 666, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True}
# event: call, function: cast, lineno: 1737, locals: {'typ': ~G, 'val': True}
# event: line, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: __get__, lineno: 687, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: call, function: helper, lineno: 279, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: line, function: helper, lineno: 281, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: call, function: __init__, lineno: 102, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 103, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 104, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 106, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 107, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': None}
# event: line, function: __init__, lineno: 108, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': None}
# event: line, function: __init__, lineno: 109, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'}
# event: return, function: __init__, lineno: 109, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'}
# event: return, function: helper, lineno: 281, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: call, function: __enter__, lineno: 130, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>}
# event: line, function: __enter__, lineno: 133, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>}
# event: line, function: __enter__, lineno: 134, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>}
# event: line, function: __enter__, lineno: 135, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>}
# event: call, function: extra_flags, lineno: 180, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192}
# event: line, function: extra_flags, lineno: 183, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192}
# event: line, function: extra_flags, lineno: 186, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: line, function: extra_flags, lineno: 187, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: line, function: extra_flags, lineno: 188, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: return, function: extra_flags, lineno: 188, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: return, function: __enter__, lineno: 135, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>}
# event: call, function: __call__, lineno: 117, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec'}
# event: line, function: __call__, lineno: 118, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec'}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0), 262144)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0), 262144)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 5, 0, 'alpha', 1), (2, 6, 0, 'alpha', 0), 524288)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 5, 0, 'alpha', 1), (2, 6, 0, 'alpha', 0), 524288)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 1048576)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 1048576)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 2097152)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 2097152)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 1, 0, 'alpha', 2), (4, 0, 0, 'alpha', 0), 4194304)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 1, 0, 'alpha', 2), (4, 0, 0, 'alpha', 0), 4194304)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 5, 0, 'beta', 1), (3, 7, 0, 'alpha', 0), 8388608)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 5, 0, 'beta', 1), (3, 7, 0, 'alpha', 0), 8388608)}
# event: line, function: __call__, lineno: 120, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: line, function: __call__, lineno: 119, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: line, function: __call__, lineno: 122, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: return, function: __call__, lineno: 122, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Module object at 0x0000016098839FC0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: call, function: compare, lineno: 3493, locals: {'code': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>}
# event: line, function: compare, lineno: 3494, locals: {'code': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>}
# event: line, function: compare, lineno: 3495, locals: {'code': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'is_async': False}
# event: return, function: compare, lineno: 3495, locals: {'code': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'is_async': False}
# event: call, function: __exit__, lineno: 139, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 140, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 141, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 142, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: call, function: extra_flags, lineno: 188, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: line, function: extra_flags, lineno: 192, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: return, function: extra_flags, lineno: 192, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: exception, function: __exit__, lineno: 142, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 143, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 144, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: return, function: __exit__, lineno: 144, locals: {'self': <contextlib._GeneratorContextManager object at 0x000001609883B1F0>, 'typ': None, 'value': None, 'traceback': None}
# event: call, function: run_code, lineno: 3541, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False}
# event: line, function: run_code, lineno: 3563, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False}
# event: line, function: run_code, lineno: 3566, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__'}
# event: line, function: run_code, lineno: 3570, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>}
# event: line, function: run_code, lineno: 3571, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>}
# event: line, function: run_code, lineno: 3572, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3573, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3574, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3577, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: call, function: user_global_ns, lineno: 1277, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: line, function: user_global_ns, lineno: 1279, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: return, function: user_global_ns, lineno: 1279, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: call, function: <module>, lineno: 1, locals: {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], '_oh': {}, '_dh': [WindowsPath('C:/Users/86137/Desktop/first')], 'In': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'open': <function open at 0x00000160971E2200>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\86137\\Desktop\\first\\Untitled.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)', 'settrace': <built-in function settrace>, 'tracer': <function tracer at 0x0000016098868F70>, 'foo': <function foo at 0x0000016098868B80>, 'old_tracer': None}
# event: line, function: <module>, lineno: 21, locals: {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], '_oh': {}, '_dh': [WindowsPath('C:/Users/86137/Desktop/first')], 'In': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'open': <function open at 0x00000160971E2200>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\86137\\Desktop\\first\\Untitled.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)', 'settrace': <built-in function settrace>, 'tracer': <function tracer at 0x0000016098868F70>, 'foo': <function foo at 0x0000016098868B80>, 'old_tracer': None}
# event: call, function: foo, lineno: 13, locals: {'bar': 10}
# event: line, function: foo, lineno: 14, locals: {'bar': 10}
# event: line, function: foo, lineno: 15, locals: {'bar': 10, 'buz': 11}
# event: line, function: foo, lineno: 16, locals: {'bar': 110, 'buz': 11}
# event: line, function: foo, lineno: 17, locals: {'bar': 110, 'buz': 11}
# event: line, function: foo, lineno: 18, locals: {'bar': 99, 'buz': 11}
# event: return, function: foo, lineno: 18, locals: {'bar': 99, 'buz': 11}
# event: return, function: <module>, lineno: 21, locals: {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], '_oh': {}, '_dh': [WindowsPath('C:/Users/86137/Desktop/first')], 'In': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'open': <function open at 0x00000160971E2200>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\86137\\Desktop\\first\\Untitled.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)', 'settrace': <built-in function settrace>, 'tracer': <function tracer at 0x0000016098868F70>, 'foo': <function foo at 0x0000016098868B80>, 'old_tracer': None}
# event: line, function: run_code, lineno: 3580, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3601, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3602, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': False}
# event: return, function: run_code, lineno: 3602, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x00000160946931B0, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': False}
# event: call, function: __get__, lineno: 676, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: __get__, lineno: 684, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: __get__, lineno: 687, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: call, function: get, lineno: 629, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 630, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 631, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 632, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: line, function: get, lineno: 666, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True}
# event: call, function: cast, lineno: 1737, locals: {'typ': ~G, 'val': True}
# event: line, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: get, lineno: 666, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True}
# event: call, function: cast, lineno: 1737, locals: {'typ': ~G, 'val': True}
# event: line, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: cast, lineno: 1745, locals: {'typ': ~G, 'val': True}
# event: return, function: __get__, lineno: 687, locals: {'self': <traitlets.traitlets.Bool object at 0x00000160971DD960>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>}
# event: call, function: helper, lineno: 279, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: line, function: helper, lineno: 281, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: call, function: __init__, lineno: 102, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 103, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 104, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 106, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}}
# event: line, function: __init__, lineno: 107, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': None}
# event: line, function: __init__, lineno: 108, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': None}
# event: line, function: __init__, lineno: 109, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'}
# event: return, function: __init__, lineno: 109, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'}
# event: return, function: helper, lineno: 281, locals: {'args': (<ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x0000016096E16170>}
# event: call, function: __enter__, lineno: 130, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>}
# event: line, function: __enter__, lineno: 133, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>}
# event: line, function: __enter__, lineno: 134, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>}
# event: line, function: __enter__, lineno: 135, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>}
# event: call, function: extra_flags, lineno: 180, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192}
# event: line, function: extra_flags, lineno: 183, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192}
# event: line, function: extra_flags, lineno: 186, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# ...
# event: line, function: __call__, lineno: 122, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Interactive object at 0x000001609883B1F0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'single', 'codeob': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: return, function: __call__, lineno: 122, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'source': <ast.Interactive object at 0x000001609883B1F0>, 'filename': 'C:\\Users\\86137\\AppData\\Local\\Temp\\ipykernel_13632\\77812729.py', 'symbol': 'single', 'codeob': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'feature': _Feature((3, 7, 0, 'beta', 1), (3, 11, 0, 'alpha', 0), 16777216)}
# event: call, function: compare, lineno: 3493, locals: {'code': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>}
# event: line, function: compare, lineno: 3494, locals: {'code': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>}
# event: line, function: compare, lineno: 3495, locals: {'code': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'is_async': False}
# event: return, function: compare, lineno: 3495, locals: {'code': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'is_async': False}
# event: call, function: __exit__, lineno: 139, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 140, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 141, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 142, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: call, function: extra_flags, lineno: 188, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: line, function: extra_flags, lineno: 192, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: return, function: extra_flags, lineno: 192, locals: {'self': <ipykernel.compiler.XCachingCompiler object at 0x00000160987EB910>, 'flags': 8192, 'turn_on_bits': 8192}
# event: exception, function: __exit__, lineno: 142, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 143, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: line, function: __exit__, lineno: 144, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: return, function: __exit__, lineno: 144, locals: {'self': <contextlib._GeneratorContextManager object at 0x0000016098839FC0>, 'typ': None, 'value': None, 'traceback': None}
# event: call, function: run_code, lineno: 3541, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False}
# event: line, function: run_code, lineno: 3563, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False}
# event: line, function: run_code, lineno: 3566, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__'}
# event: line, function: run_code, lineno: 3570, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>}
# event: line, function: run_code, lineno: 3571, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>}
# event: line, function: run_code, lineno: 3572, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3573, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3574, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: line, function: run_code, lineno: 3577, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>, 'code_obj': <code object <module> at 0x0000016094690710, file "C:\Users\86137\AppData\Local\Temp\ipykernel_13632\77812729.py", line 1>, 'result': <ExecutionResult object at 16098863a60, execution_count=1 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 16098863c70, raw_cell="#!/usr/bin/env python
# # coding: utf-8
#
# from sys im.." store_history=True silent=False shell_futures=True cell_id=da1f066a-341e-4be0-a95d-ba04dfbcef98> result=None>, 'async_': False, '__tracebackhide__': '__ipython_bottom__', 'old_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x000001609414EC50>>, 'outflag': True}
# event: call, function: user_global_ns, lineno: 1277, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: line, function: user_global_ns, lineno: 1279, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: return, function: user_global_ns, lineno: 1279, locals: {'self': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>}
# event: call, function: <module>, lineno: 1, locals: {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], '_oh': {}, '_dh': [WindowsPath('C:/Users/86137/Desktop/first')], 'In': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'open': <function open at 0x00000160971E2200>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\86137\\Desktop\\first\\Untitled.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)', 'settrace': <built-in function settrace>, 'tracer': <function tracer at 0x0000016098868F70>, 'foo': <function foo at 0x0000016098868B80>, 'old_tracer': None}
# event: line, function: <module>, lineno: 22, locals: {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], '_oh': {}, '_dh': [WindowsPath('C:/Users/86137/Desktop/first')], 'In': ['', '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000160987EB7F0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000160988382B0>, 'open': <function open at 0x00000160971E2200>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\86137\\Desktop\\first\\Untitled.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': '#!/usr/bin/env python\n# coding: utf-8\n\nfrom sys import settrace\n\ndef tracer(frame, event, arg):\n    func_name = frame.f_code.co_name\n    line_no = frame.f_lineno\n    f_locals = frame.f_locals\n    print(f"event: {event}, function: {func_name}, lineno: {line_no}, locals: {f_locals}")\n    return tracer\n\ndef foo(bar):\n    buz = bar + 1\n    bar *= buz\n    if bar > buz:\n        bar -= buz\n    return bar + buz\n\nold_tracer = settrace(tracer)\nfoo(10)\nsettrace(old_tracer)', 'settrace': <built-in function settrace>, 'tracer': <function tracer at 0x0000016098868F70>, 'foo': <function foo at 0x0000016098868B80>, 'old_tracer': None}
